# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilkenny/A.I.-Forecasting-Modelling-with-Great-Britain-s-System-Operator-Generation-Outputs-NESO-Data-Portal-/blob/main/notebooks_01_api_discovery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Publication-aware machine-learning pipeline for enhancing Great Britain day-ahead gas-demand forecasts during cold, low-wind and high gas-for-power conditions**

# %%
# !pip install pandas numpy requests matplotlib plotly pyarrow scikit-learn xgboost

# %%
# !pip install tensorflow sqlalchemy psycopg2-binary mlflow
